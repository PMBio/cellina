# %% [markdown]
# # Perturbation LOO Evaluation — cellina_graph (GCN)
#
# Evaluates the perturbation model on a held-out cell type in the brain regions.
# For each cell type we compute the top-100 pseudobulk logFC genes (target vs donor),
# perturb donor cells' **raw counts** in `layers['counts_cf_*']` via `make_perturbed_expression`,
# then pass that layer through the GCN at inference time.
#
# The GCN aggregates perturbed counts over the spatial graph — no explicit pseudobulk step
# is needed (unlike the MLP version in `perturb_loo_brain.ipynb`).

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.append('../../scripts')

import os
import numpy as np
import pandas as pd
import scanpy as sc
import decoupler as dc
import matplotlib.pyplot as plt
import scvi

import cellina_graph
from cellina_graph import CellinaModel, make_perturbed_expression
from cellina_graph._spatial_utils import spatial_neighbors

from perturb_utils import load_merfish_brain, split_indices, compute_cf_logfc

plt.rcParams['figure.dpi'] = 75
scvi.settings.seed = 0
print(cellina_graph.__version__)
# Out:
# INFO: Seed set to 0
# 2026-04-28 16:04:30 | [INFO] Seed set to 0
# 0.0.7

# %%
# ── Brain LOO Config ─────────────────────────────────────────────────────────
labels_key       = 'cell_type'
domains_key      = 'major_brain_region'
holdout_celltype = 'glutamatergic neuron'
donor_region     = 'Isocortex'
target_regions   = ['Thalamus', 'Hippocampus']
top_n_perturb    = 100   # genes used to perturb spatial context
top_n            = 100   # genes used to evaluate metrics
min_cells        = 50    # minimum cells per domain per cell type to evaluate
batch_size       = 512
library_size     = 1e4
base_path        = 'results/perturb_loo_brain_graph'
exp_name         = f"{donor_region}_to_{'_'.join(target_regions)}"
save_path        = f"{base_path}/trained/{exp_name}_{holdout_celltype.replace(' ', '_')}"

# %%
adata = load_merfish_brain(labels_key=labels_key, domains_key=domains_key)

# %%
sc.pl.spatial(adata, color=[labels_key, domains_key], spot_size=20, wspace=0.6)

# %%
adata.obs[[labels_key, domains_key]].groupby([labels_key, domains_key]).size().sort_values(ascending=False).head(20)
# Out:
# /tmp/ipykernel_3758001/1927349148.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   adata.obs[[labels_key, domains_key]].groupby([labels_key, domains_key]).size().sort_values(ascending=False).head(20)
# cell_type             major_brain_region
# glutamatergic neuron  Isocortex             7730
#                       Thalamus              3521
#                       Hippocampus           3203
# oligodendrocyte       Fiber_tracts          2455
#                       Thalamus              1769
# glutamatergic neuron  Cortical_subplate     1506
#                       Hypothalamus          1349
# astrocyte             Isocortex             1295
# endothelial cell      Isocortex             1256
# astrocyte             Thalamus              1230
# GABAergic neuron      Striatum              1142
#                       Hypothalamus          1123
# astrocyte             Hippocampus           1081
# GABAergic neuron      Isocortex             1041
# endothelial cell      Thalamus               996
# astrocyte             Fiber_tracts           933
# glutamatergic neuron  Olfactory              878
# oligodendrocyte       Hippocampus            695
# glutamatergic neuron  Striatum               688
# oligodendrocyte       Hypothalamus           633
# dtype: int64

# %%
# cellina_graph reads raw counts directly from layers['counts'] at training/inference time.
# No need to normalize adata.X here — we reset it to raw counts when needed.

# %% [markdown]
# ## Three-Region LOO: Isocortex → Thalamus & Hippocampus
#
# `glutamatergic neuron` is held out from **both** Thalamus and Hippocampus simultaneously.
# The model sees glu. neurons only in Isocortex, then we test transfer to each target region.
# We also compare real vs CF logFC vectors *between* the two target regions to see whether
# the model can differentiate their distinct spatial contexts.

# %%
all_regions = [donor_region] + target_regions
adata_3r = adata[adata.obs[domains_key].isin(all_regions)].copy()
print(f"Subset: {adata_3r.shape}")
print(adata_3r.obs.groupby([domains_key, labels_key]).size().unstack(fill_value=0))
# Out:
# Subset: (29374, 1120)
# cell_type           neuroblast (sensu Vertebrata)  ependymal cell  \
# major_brain_region
# Hippocampus                                   186             194
# Isocortex                                       0               0
# Thalamus                                        0              39
#
# cell_type           endothelial cell  astrocyte  oligodendrocyte  \
# major_brain_region
# Hippocampus                      553       1081              695
# Isocortex                       1256       1295              628
# Thalamus                         996       1230             1769
#
# cell_type           microglial cell  smooth muscle cell  macrophage  \
# major_brain_region
# Hippocampus                     275                  38          17
# Isocortex                       529                  82          25
# Thalamus                        275                  84          19
#
# cell_type           dendritic cell  lymphocyte  monocyte  GABAergic neuron  \
# major_brain_region
# Hippocampus                      2           9         0               294
# Isocortex                        3           9         2              1041
# Thalamus                         0           7         0               467
#
# cell_type           pericyte  glutamatergic neuron  \
# major_brain_region
# Hippocampus              116                  3203
# Isocortex                258                  7730
# Thalamus                 217                  3521
#
# cell_type           choroid plexus epithelial cell  \
# major_brain_region
# Hippocampus                                    156
# Isocortex                                        0
# Thalamus                                         0
#
# cell_type           oligodendrocyte precursor cell  glycinergic neuron  \
# major_brain_region
# Hippocampus                                    198                   0
# Isocortex                                      308                   1
# Thalamus                                       269                   2
#
# cell_type           vascular leptomeningeal cell
# major_brain_region
# Hippocampus                                   80
# Isocortex                                    147
# Thalamus                                      68
# /tmp/ipykernel_3758001/2417491457.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(adata_3r.obs.groupby([domains_key, labels_key]).size().unstack(fill_value=0))

# %%
sc.pl.spatial(adata_3r, color=[labels_key, domains_key], spot_size=20, wspace=0.6)

# %%
# Spatial graph on the 3-region subset (CCF coords in microns — no pixel conversion).
# Writes connectivity to adata_3r.obsp['spatial_connectivities'] (default key_added='spatial').
spatial_neighbors(adata_3r, bandwidth=100, max_neighbours=200, standardize=False)
# No compute_spatial_features needed — the GCN aggregates counts over the graph at inference.

# Hold out glutamatergic neurons from BOTH Thalamus AND Hippocampus simultaneously
train_idx, val_idx, test_idx = split_indices(
    adata_3r,
    holdout_celltype=holdout_celltype,
    labels_key=labels_key,
    domains_key=domains_key,
    holdout_domains=tuple(target_regions),  # ('Thalamus', 'Hippocampus')
)
print(f"train={len(train_idx):,}  val={len(val_idx):,}  test (holdout)={len(test_idx):,}")
print(f"Holdout = {holdout_celltype} in {target_regions}: {adata_3r.obs['is_holdout'].sum()} cells")
# Out:
# train=20,385  val=2,265  test (holdout)=6,724
# Holdout = glutamatergic neuron in ['Thalamus', 'Hippocampus']: 6724 cells

# %%
CellinaModel.setup_anndata(
    adata_3r,
    batch_key=None,
    labels_key=labels_key,
    domains_key=domains_key,
    layer='counts',
    spatial_connectivities_key='spatial_connectivities',  # written by spatial_neighbors above
)

model = CellinaModel(
    adata_3r,
    n_latent=20,
    classifier_lambda=1,
    discriminator_lambda=1,
    link_prediction_weight=1.0,    # spatial loss on s (replaces domain_classifier_lambda)
    spatial_loss_type='domain_clf',
    n_layers=2,
    condition_on_intrinsic=False,
)

model.train(
    max_epochs=100,
    check_val_every_n_epoch=1,
    early_stopping=True,
    early_stopping_patience=5,
    early_stopping_monitor='vae_loss_validation',
    plan_kwargs={'lr': 1e-3, 'weight_decay': 0.0001, 'normalize_losses': True},
    datasplitter_kwargs={"external_indexing": [train_idx, val_idx, test_idx]},
    enable_checkpointing=True,
    batch_size=batch_size,
    devices=[0],
)

os.makedirs(save_path, exist_ok=True)
model.save(save_path, overwrite=True)
# Out:
# INFO     cellina: The Cellina model has been initialized with adversarial domain forgetting with edge prediction
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/scvi/data/fields/_dataframe_field.py:186: UserWarning: Category 10 in adata.obs['_scvi_labels'] has fewer than 3 cells. Models may not train properly.
#   categorical_mapping = _make_column_categorical(
# INFO: GPU available: True (cuda), used: True
# 2026-04-28 16:04:57 | [INFO] GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# 2026-04-28 16:04:57 | [INFO] TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# 2026-04-28 16:04:57 | [INFO] HPU available: False, using: 0 HPUs
# INFO: You are using a CUDA device ('NVIDIA GeForce RTX 4090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# 2026-04-28 16:04:57 | [INFO] You are using a CUDA device ('NVIDIA GeForce RTX 4090') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# 2026-04-28 16:04:57 | [INFO] LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
# Training:   0%|          | 0/100 [00:00<?, ?it/s]
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26961. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27322. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27668. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27466. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 20945. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26413. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27304. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26854. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26912. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27407. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27210. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26922. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27542. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26404. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27101. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27769. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 25951. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27040. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26571. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26874. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26807. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27045. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27200. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27776. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27405. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27531. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27308. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27540. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26250. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27861. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27514. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26967. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27891. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26794. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27720. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27109. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27028. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26605. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26533. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27625. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26971. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26388. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26956. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27072. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 25888. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27171. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26702. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26940. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27056. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27274. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27202. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26877. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27518. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27856. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27770. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27462. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27496. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27789. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26763. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27297. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27451. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27128. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26813. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26765. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27103. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27473. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26742. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27066. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27262. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 28096. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27906. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27115. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26952. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27187. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26919. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26989. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27218. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27310. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27361. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26756. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26755. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26337. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27326. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27595. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27279. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27207. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26808. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26617. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27014. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27019. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27559. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27191. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27159. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27670. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26630. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26654. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27876. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26420. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27362. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27289. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27562. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26475. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26898. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27350. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27303. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27075. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27642. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27519. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27223. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27134. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27016. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27654. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26726. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26633. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26843. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27808. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26838. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 25927. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27013. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26766. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27380. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27330. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26762. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27726. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27217. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26680. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27766. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27853. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27006. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27482. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27201. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27233. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27037. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27714. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27469. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26760. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27042. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26969. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26831. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27803. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27441. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27692. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26895. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26979. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27275. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27363. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27284. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27579. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26976. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26681. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26518. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27081. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26825. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27539. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27517. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26600. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# ...
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27468. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27358. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26539. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26314. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26932. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26950. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27477. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26343. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27170. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27129. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27543. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27301. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26202. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26601. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27415. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26954. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26540. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27251. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27117. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27160. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27307. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27623. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27917. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26526. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 25906. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27471. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26820. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27328. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26810. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27609. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26821. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27195. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 28052. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26115. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26638. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 25751. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27397. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26516. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27249. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27294. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27198. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27353. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27389. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27260. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26846. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27443. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26914. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27622. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26894. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26947. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27204. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27243. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 26532. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/lightning/pytorch/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 27611. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Monitored metric vae_loss_validation did not improve in the last 5 records. Best score: 406.162. Signaling Trainer to stop.

# %%
model.history_['spatial_loss_validation'].plot()
# Out:
# <Axes: xlabel='epoch'>

# %%
pdata = dc.pp.pseudobulk(
    adata=adata_3r,
    sample_col=domains_key,
    groups_col=labels_key,
    mode='sum',
    layer='counts',
)
sc.pp.normalize_total(pdata, target_sum=1e4)
sc.pp.log1p(pdata)

def shared_types(target):
    return [
        ct for ct in pdata.obs[labels_key].unique()
        if ((pdata.obs[domains_key] == donor_region) & (pdata.obs[labels_key] == ct)).any()
        and ((pdata.obs[domains_key] == target) & (pdata.obs[labels_key] == ct)).any()
    ]

def compute_logfc_df(target):
    cts = shared_types(target)
    return pd.concat([
        pd.Series(
            (
                pdata[(pdata.obs[domains_key] == target) & (pdata.obs[labels_key] == ct)].X
                - pdata[(pdata.obs[domains_key] == donor_region) & (pdata.obs[labels_key] == ct)].X
            ).flatten(),
            index=pdata.var_names,
            name=ct,
        )
        for ct in cts
    ], axis=1).T

logfc_dfs = {tgt: compute_logfc_df(tgt) for tgt in target_regions}
for tgt, df in logfc_dfs.items():
    print(f"{tgt}: {df.shape}  types: {sorted(df.index.tolist())}")
# Out:
# Thalamus: (18, 1120)  types: ['GABAergic neuron', 'astrocyte', 'choroid plexus epithelial cell', 'dendritic cell', 'endothelial cell', 'ependymal cell', 'glutamatergic neuron', 'glycinergic neuron', 'lymphocyte', 'macrophage', 'microglial cell', 'monocyte', 'neuroblast (sensu Vertebrata)', 'oligodendrocyte', 'oligodendrocyte precursor cell', 'pericyte', 'smooth muscle cell', 'vascular leptomeningeal cell']
# Hippocampus: (18, 1120)  types: ['GABAergic neuron', 'astrocyte', 'choroid plexus epithelial cell', 'dendritic cell', 'endothelial cell', 'ependymal cell', 'glutamatergic neuron', 'glycinergic neuron', 'lymphocyte', 'macrophage', 'microglial cell', 'monocyte', 'neuroblast (sensu Vertebrata)', 'oligodendrocyte', 'oligodendrocyte precursor cell', 'pericyte', 'smooth muscle cell', 'vascular leptomeningeal cell']
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/scanpy/preprocessing/_normalization.py:234: UserWarning: Some cells have zero counts
#   warn(UserWarning("Some cells have zero counts"))

# %%
for tgt in target_regions:
    logfc_series_dict = {}
    for ct in logfc_dfs[tgt].index:
        s = logfc_dfs[tgt].loc[ct]
        top_genes = s.abs().nlargest(top_n_perturb).index.tolist()
        logfc_series_dict[ct] = s[top_genes]

    # Reset X to raw counts — make_perturbed_expression reads adata.X
    adata_3r.X = adata_3r.layers['counts'].copy()

    make_perturbed_expression(
        adata_3r,
        perturbations=logfc_series_dict,
        groupby=labels_key,
        layer_key=f'counts_cf_{tgt.lower()}',
        base=np.e,
    )
    print(f"CF features stored: adata_3r.layers['counts_cf_{tgt.lower()}']")
# Out:
# CF features stored: adata_3r.layers['counts_cf_thalamus']
# CF features stored: adata_3r.layers['counts_cf_hippocampus']

# %%
all_rows = []
logfcs_by_target = {}
adata_3r.X = adata_3r.layers['counts'].copy()  # ensure raw counts before perturbation/inference
sc.pp.normalize_total(adata_3r, target_sum=library_size, inplace=True)

for tgt in target_regions:
    cell_types = logfc_dfs[tgt].index.tolist()
    cf_layer_key = f'counts_cf_{tgt.lower()}'
    logfcs = {}

    for ct in sorted(cell_types):
        ref_mask = (adata_3r.obs[labels_key] == ct) & (adata_3r.obs[domains_key] == donor_region)
        tgt_mask = (adata_3r.obs[labels_key] == ct) & (adata_3r.obs[domains_key] == tgt)

        if ct == holdout_celltype:
            tgt_mask = tgt_mask & adata_3r.obs['is_holdout']

        ref_idx = np.where(ref_mask.values)[0]
        tgt_idx = np.where(tgt_mask.values)[0]

        if len(ref_idx) < min_cells or len(tgt_idx) < min_cells:
            print(f"  skip {ct} in {tgt}: donor={len(ref_idx)}, target={len(tgt_idx)}")
            continue

        print(f"  {tgt} / {ct}: donor={len(ref_idx)}, target={len(tgt_idx)}")

        ref_expr = adata_3r[ref_idx].X
        ref_expr = ref_expr.toarray() if hasattr(ref_expr, 'toarray') else ref_expr

        pert_expr = model.get_perturbed_expression(
            adata=adata_3r, indices=ref_idx,
            cf_layer=cf_layer_key,
            batch_size=batch_size, library_size=library_size,
        )
        cf_expr = model.get_normalized_expression(
            indices=tgt_idx, batch_size=batch_size, library_size=library_size,
        )

        stats = compute_cf_logfc(
            ref_expr, pert_expr, cf_expr,
            top_n=top_n,
            gene_names=adata_3r.var_names.tolist(),
        )

        all_rows.append(dict(
            target=tgt, cell_type=ct, holdout=(ct == holdout_celltype),
            n_donor=len(ref_idx), n_target=len(tgt_idx),
            pearson_r=stats['pearson_r'], spearman_r=stats['spearman_r'],
            precision=stats['precision'], rmse=stats['rmse'],
        ))
        logfcs[ct] = stats

    logfcs_by_target[tgt] = logfcs

results_df = pd.DataFrame(all_rows).sort_values(['target', 'pearson_r'], ascending=[True, False]).reset_index(drop=True)
results_df
# Out:
#   Thalamus / GABAergic neuron: donor=1041, target=467
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   Thalamus / astrocyte: donor=1295, target=1230
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   skip choroid plexus epithelial cell in Thalamus: donor=0, target=0
#   skip dendritic cell in Thalamus: donor=3, target=0
#   Thalamus / endothelial cell: donor=1256, target=996
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   skip ependymal cell in Thalamus: donor=0, target=39
#   Thalamus / glutamatergic neuron: donor=7730, target=3521
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   skip glycinergic neuron in Thalamus: donor=1, target=2
#   skip lymphocyte in Thalamus: donor=9, target=7
#   skip macrophage in Thalamus: donor=25, target=19
#   Thalamus / microglial cell: donor=529, target=275
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   skip monocyte in Thalamus: donor=2, target=0
#   skip neuroblast (sensu Vertebrata) in Thalamus: donor=0, target=0
#   Thalamus / oligodendrocyte: donor=628, target=1769
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   Thalamus / oligodendrocyte precursor cell: donor=308, target=269
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   Thalamus / pericyte: donor=258, target=217
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   Thalamus / smooth muscle cell: donor=82, target=84
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   Thalamus / vascular leptomeningeal cell: donor=147, target=68
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   Hippocampus / GABAergic neuron: donor=1041, target=294
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   Hippocampus / astrocyte: donor=1295, target=1081
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   skip choroid plexus epithelial cell in Hippocampus: donor=0, target=156
#   skip dendritic cell in Hippocampus: donor=3, target=2
#   Hippocampus / endothelial cell: donor=1256, target=553
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   skip ependymal cell in Hippocampus: donor=0, target=194
#   Hippocampus / glutamatergic neuron: donor=7730, target=3203
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   skip glycinergic neuron in Hippocampus: donor=1, target=0
#   skip lymphocyte in Hippocampus: donor=9, target=9
#   skip macrophage in Hippocampus: donor=25, target=17
#   Hippocampus / microglial cell: donor=529, target=275
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   skip monocyte in Hippocampus: donor=2, target=0
#   skip neuroblast (sensu Vertebrata) in Hippocampus: donor=0, target=186
#   Hippocampus / oligodendrocyte: donor=628, target=695
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   Hippocampus / oligodendrocyte precursor cell: donor=308, target=198
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   Hippocampus / pericyte: donor=258, target=116
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#   skip smooth muscle cell in Hippocampus: donor=82, target=38
#   Hippocampus / vascular leptomeningeal cell: donor=147, target=80
# /data/ddimitrov/software/miniforge3/envs/cellina_edge/lib/python3.10/site-packages/torch_geometric/loader/neighbor_loader.py:229: UserWarning: The usage of the 'directed' argument in 'NeighborSampler' is deprecated. Use `subgraph_type='induced'` instead.
#   neighbor_sampler = NeighborSampler(
#          target                       cell_type  holdout  n_donor  n_target  \
# 0   Hippocampus    vascular leptomeningeal cell    False      147        80
# 1   Hippocampus                 oligodendrocyte    False      628       695
# 2   Hippocampus                 microglial cell    False      529       275
# 3   Hippocampus                       astrocyte    False     1295      1081
# 4   Hippocampus  oligodendrocyte precursor cell    False      308       198
# 5   Hippocampus            glutamatergic neuron     True     7730      3203
# 6   Hippocampus                endothelial cell    False     1256       553
# 7   Hippocampus                        pericyte    False      258       116
# 8   Hippocampus                GABAergic neuron    False     1041       294
# 9      Thalamus                 oligodendrocyte    False      628      1769
# 10     Thalamus    vascular leptomeningeal cell    False      147        68
# 11     Thalamus            glutamatergic neuron     True     7730      3521
# 12     Thalamus                 microglial cell    False      529       275
# 13     Thalamus                       astrocyte    False     1295      1230
# 14     Thalamus                GABAergic neuron    False     1041       467
# 15     Thalamus              smooth muscle cell    False       82        84
# 16     Thalamus  oligodendrocyte precursor cell    False      308       269
# 17     Thalamus                        pericyte    False      258       217
# 18     Thalamus                endothelial cell    False     1256       996
#
#     pearson_r  spearman_r  precision      rmse
# 0    0.964585    0.824614       0.74  0.369029
# 1    0.945872    0.907843       0.55  0.570099
# 2    0.937228    0.838620       0.69  0.512953
# 3    0.935599    0.789655       0.63  0.642244
# 4    0.923630    0.854233       0.70  0.367739
# 5    0.915533    0.751311       0.55  0.969339
# 6    0.908176    0.753447       0.71  0.486233
# 7    0.869624    0.711947       0.67  0.429124
# 8    0.709917    0.511167       0.57  0.776046
# 9    0.950058    0.901194       0.62  0.729840
# 10   0.933382    0.772853       0.60  0.549020
# 11   0.925808    0.832247       0.38  1.772161
# 12   0.912775    0.854053       0.60  0.910579
# 13   0.881710    0.693309       0.56  1.042579
# 14   0.879535    0.800468       0.49  1.366756
# 15   0.878613    0.578878       0.70  0.454480
# 16   0.872133    0.742982       0.59  0.906785
# 17   0.837209    0.668083       0.58  0.686058
# 18   0.764691    0.547495       0.64  0.802557

# %%
# target	cell_type	holdout	n_donor	n_target	pearson_r	spearman_r	precision	rmse
# 0	Hippocampus	oligodendrocyte precursor cell	False	308	198	0.986210	0.884752	0.73	0.288361
# 1	Hippocampus	microglial cell	False	529	275	0.984087	0.907711	0.79	0.352249
# 2	Hippocampus	pericyte	False	258	116	0.976271	0.873627	0.69	0.283382
# 3	Hippocampus	endothelial cell	False	1256	553	0.975080	0.769121	0.74	0.273195
# 4	Hippocampus	astrocyte	False	1295	1081	0.970911	0.864746	0.69	0.520878
# 5	Hippocampus	oligodendrocyte	False	628	695	0.954757	0.647777	0.75	0.591368
# 6	Hippocampus	vascular leptomeningeal cell	False	147	80	0.953718	0.857834	0.71	0.410886
# 7	Hippocampus	glutamatergic neuron	True	7730	3203	0.914149	0.848593	0.60	0.931742
# 8	Hippocampus	GABAergic neuron	False	1041	294	0.876373	0.796076	0.57	0.571250
# 9	Thalamus	vascular leptomeningeal cell	False	147	68	0.993187	0.954803	0.87	0.176418
# 10	Thalamus	oligodendrocyte precursor cell	False	308	269	0.992090	0.958416	0.88	0.382310
# 11	Thalamus	oligodendrocyte	False	628	1769	0.991034	0.951755	0.90	0.294141
# 12	Thalamus	endothelial cell	False	1256	996	0.990296	0.970753	0.83	0.367669
# 13	Thalamus	microglial cell	False	529	275	0.988299	0.957420	0.81	0.440239
# 14	Thalamus	astrocyte	False	1295	1230	0.988102	0.951227	0.77	0.556547
# 15	Thalamus	smooth muscle cell	False	82	84	0.986242	0.937246	0.77	0.247030
# 16	Thalamus	pericyte	False	258	217	0.983647	0.940738	0.75	0.357924
# 17	Thalamus	glutamatergic neuron	True	7730	3521	0.949289	0.863102	0.55	1.317171
# 18	Thalamus	GABAergic neuron	False	1041	467	0.915813	0.871851	0.56	1.049374

# %%
results_df.groupby(['target', 'holdout'])[['pearson_r', 'spearman_r', 'precision', 'rmse']].mean()
# Out:
#                      pearson_r  spearman_r  precision      rmse
# target      holdout
# Hippocampus False     0.899329    0.773941   0.657500  0.519184
#             True      0.915533    0.751311   0.550000  0.969339
# Thalamus    False     0.878901    0.728813   0.597778  0.827628
#             True      0.925808    0.832247   0.380000  1.772161

# %%
# 	pearson_r	spearman_r	precision	rmse
# target	holdout				
# Hippocampus	False	0.959676	0.825206	0.708750	0.411446
# True	0.914149	0.848593	0.600000	0.931742
# Thalamus	False	0.980968	0.943801	0.793333	0.430184
# True	0.949289	0.863102	0.550000	1.317171

# %%
for tgt in target_regions:
    logfcs = logfcs_by_target[tgt]
    sub_df = results_df[results_df['target'] == tgt].reset_index(drop=True)

    ncols = 4
    nrows = (len(sub_df) + ncols - 1) // ncols
    fig, axes = plt.subplots(nrows, ncols, figsize=(4 * ncols, 4 * nrows))
    axes = axes.flatten()

    for i, row in sub_df.iterrows():
        ct = row['cell_type']
        ax = axes[i]
        real = logfcs[ct]['real_logfc']
        pred = logfcs[ct]['pred_logfc']
        mask = logfcs[ct]['top_n_mask']
        if mask is not None:
            real, pred = real[mask], pred[mask]

        color = '#e05c5c' if row['holdout'] else '#4C72B0'
        ax.scatter(real, pred, s=4, alpha=0.4, color=color)
        m, b = np.polyfit(real, pred, 1)
        x_lo, x_hi = real.min(), real.max()
        ax.plot([x_lo, x_hi], [m * x_lo + b, m * x_hi + b], 'k--', lw=0.8)
        ax.axhline(0, color='grey', lw=0.5, ls=':')
        ax.axvline(0, color='grey', lw=0.5, ls=':')

        title = f"{ct}{'  [holdout]' if row['holdout'] else ''}"
        ax.set_title(
            f"{title}\nr={row['pearson_r']:.3f}, ρ={row['spearman_r']:.3f}, prec={row['precision']:.2f}",
            fontsize=10,
        )
        ax.set_xlabel(f'real logFC ({tgt} − {donor_region})', fontsize=9)
        ax.set_ylabel('perturb logFC (perturbed − donor)', fontsize=9)

    for j in range(i + 1, len(axes)):
        axes[j].set_visible(False)

    plt.suptitle(
        f"Brain LOO  |  {donor_region} → {tgt}  |  holdout: {holdout_celltype}\n"
        f"top_n_perturb={top_n_perturb}, top_n={top_n}",
        y=1.01,
    )
    plt.tight_layout()
    plt.show()

# %%
from scipy.stats import pearsonr, spearmanr

# Cell types evaluated in both target regions
common_cts = sorted(
    set(logfcs_by_target[target_regions[0]].keys())
    & set(logfcs_by_target[target_regions[1]].keys())
)

cross_rows = []
for ct in common_cts:
    s0 = logfcs_by_target[target_regions[0]][ct]   # Thalamus
    s1 = logfcs_by_target[target_regions[1]][ct]   # Hippocampus

    # Full-gene logFC vectors (not filtered by top_n_mask)
    real_r,   _ = pearsonr(s0['real_logfc'], s1['real_logfc'])
    real_rho, _ = spearmanr(s0['real_logfc'], s1['real_logfc'])
    cf_r,     _ = pearsonr(s0['pred_logfc'], s1['pred_logfc'])
    cf_rho,   _ = spearmanr(s0['pred_logfc'], s1['pred_logfc'])

    cross_rows.append(dict(
        cell_type=ct, holdout=(ct == holdout_celltype),
        real_pearson_r=real_r, real_spearman_r=real_rho,
        cf_pearson_r=cf_r,     cf_spearman_r=cf_rho,
    ))

cross_df = pd.DataFrame(cross_rows).sort_values('real_pearson_r', ascending=False).reset_index(drop=True)
print(f"Cross-region logFC similarity ({target_regions[0]} vs {target_regions[1]}):")
display(cross_df)

# Scatter: real-real vs CF-CF similarity per cell type
fig, ax = plt.subplots(figsize=(5, 5))
for _, row in cross_df.iterrows():
    color = '#e05c5c' if row['holdout'] else '#4C72B0'
    ax.scatter(row['real_pearson_r'], row['cf_pearson_r'], s=60, color=color, zorder=3)
    ax.annotate(row['cell_type'], (row['real_pearson_r'], row['cf_pearson_r']),
                fontsize=8, ha='left', va='bottom')

lim = [min(cross_df[['real_pearson_r', 'cf_pearson_r']].min()) - 0.05,
       max(cross_df[['real_pearson_r', 'cf_pearson_r']].max()) + 0.05]
ax.plot(lim, lim, color='grey', ls='--', lw=0.8)
ax.set_xlim(lim); ax.set_ylim(lim)
ax.set_xlabel(f'real logFC similarity ({target_regions[0]} vs {target_regions[1]})', fontsize=10)
ax.set_ylabel(f'CF logFC similarity ({target_regions[0]} vs {target_regions[1]})', fontsize=10)
ax.set_title(
    'Cross-region logFC similarity: real vs CF\n'
    '(above diagonal → model over-conflates regions; below → over-differentiates)',
    fontsize=10,
)
plt.tight_layout()
plt.show()
# Out:
# Cross-region logFC similarity (Thalamus vs Hippocampus):
#                         cell_type  holdout  real_pearson_r  real_spearman_r  \
# 0    vascular leptomeningeal cell    False        0.913349         0.918083
# 1                 oligodendrocyte    False        0.814510         0.815957
# 2                        pericyte    False        0.783785         0.813819
# 3  oligodendrocyte precursor cell    False        0.761292         0.761691
# 4                 microglial cell    False        0.728804         0.739700
# 5                endothelial cell    False        0.695319         0.709021
# 6            glutamatergic neuron     True        0.689304         0.703343
# 7                       astrocyte    False        0.666378         0.667276
# 8                GABAergic neuron    False        0.631049         0.648689
#
#    cf_pearson_r  cf_spearman_r
# 0      0.992796       0.990844
# 1      0.961539       0.958229
# 2      0.975726       0.972687
# 3      0.960279       0.948972
# 4      0.942250       0.931889
# 5      0.964959       0.955030
# 6      0.910959       0.895098
# 7      0.930812       0.915390
# 8      0.937319       0.913524

# %%
os.makedirs(base_path, exist_ok=True)
results_df.to_csv(f"{base_path}/brain_loo_{exp_name}_metrics.csv", index=False)
cross_df.to_csv(f"{base_path}/brain_loo_{exp_name}_crossregion.csv", index=False)
print(f"Saved metrics:      {base_path}/brain_loo_{exp_name}_metrics.csv")
print(f"Saved cross-region: {base_path}/brain_loo_{exp_name}_crossregion.csv")
# Out:
# Saved metrics:      results/perturb_loo_brain_graph/brain_loo_Isocortex_to_Thalamus_Hippocampus_metrics.csv
# Saved cross-region: results/perturb_loo_brain_graph/brain_loo_Isocortex_to_Thalamus_Hippocampus_crossregion.csv
